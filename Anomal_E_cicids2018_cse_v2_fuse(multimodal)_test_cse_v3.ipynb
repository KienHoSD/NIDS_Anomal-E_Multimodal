# %%
import pandas as pd
import numpy as np
import torch
from sklearn import preprocessing
from dgl.data import DGLDataset
import dgl
import time
import networkx as nx
import category_encoders as ce
import torch.nn as nn
import torch.nn.functional as F
import dgl.function as fn
import torch
import tqdm
import math

from typing import *
from sklearn.preprocessing import StandardScaler, Normalizer
import socket
import struct
import random
from sklearn.model_selection import train_test_split

# %%
file_name = "NF-CSE-CIC-IDS2018-v2.parquet"
data = pd.read_parquet(file_name)

# %%
##ADDED
file_name_test = "NF-CSE-CIC-IDS2018-v3.parquet"
test_data = pd.read_parquet(file_name_test)
##

# %%
data.Label.value_counts()
# Out:
# Label
# 0    16635567
# 1     2258141
# Name: count, dtype: int64

# %%
##ADDED
test_data.Label.value_counts()
##
# Out:
# Label
# 0    17514626
# 1     2600903
# Name: count, dtype: int64

# %%
data.rename(columns=lambda x: x.strip(), inplace=True)
data['IPV4_SRC_ADDR'] = data["IPV4_SRC_ADDR"].apply(str)
data['L4_SRC_PORT'] = data["L4_SRC_PORT"].apply(str)
data['IPV4_DST_ADDR'] = data["IPV4_DST_ADDR"].apply(str)
data['L4_DST_PORT'] = data["L4_DST_PORT"].apply(str)

# %%
##ADDED
test_data.rename(columns=lambda x: x.strip(), inplace=True)
test_data['IPV4_SRC_ADDR'] = test_data["IPV4_SRC_ADDR"].apply(str)
test_data['L4_SRC_PORT'] = test_data["L4_SRC_PORT"].apply(str)
test_data['IPV4_DST_ADDR'] = test_data["IPV4_DST_ADDR"].apply(str)
test_data['L4_DST_PORT'] = test_data["L4_DST_PORT"].apply(str)
##

# %%
data.drop(columns=["L4_SRC_PORT", "L4_DST_PORT"], inplace=True)

# %%
##ADDED
test_data.drop(columns=["L4_SRC_PORT", "L4_DST_PORT"], inplace=True)
##

# %%
data.Attack.unique()
# Out:
# array(['SSH-Bruteforce', 'Benign', 'DDoS attacks-LOIC-HTTP',
#        'DDOS attack-HOIC', 'DoS attacks-Slowloris', 'DoS attacks-Hulk',
#        'FTP-BruteForce', 'Infilteration', 'Bot', 'DoS attacks-GoldenEye',
#        'Brute Force -Web', 'DoS attacks-SlowHTTPTest', 'SQL Injection',
#        'DDOS attack-LOIC-UDP', 'Brute Force -XSS'], dtype=object)

# %%
##ADDED
test_data.Attack.unique()
##
# Out:
# array(['Benign', 'FTP-BruteForce', 'SSH-Bruteforce',
#        'DoS_attacks-GoldenEye', 'DoS_attacks-Slowloris',
#        'DoS_attacks-SlowHTTPTest', 'DoS_attacks-Hulk',
#        'DDoS_attacks-LOIC-HTTP', 'DDOS_attack-LOIC-UDP',
#        'DDOS_attack-HOIC', 'Brute_Force_-Web', 'Brute_Force_-XSS',
#        'SQL_Injection', 'Infilteration', 'Bot'], dtype=object)

# %%
##ADDED
data["Attack"] = data["Attack"].str.replace(" ", "_")
##

# %%
data = data.groupby(by='Attack').sample(frac=0.02, random_state=13)

# %%
##ADDED
test_data = test_data.groupby(by='Attack').sample(frac=0.02, random_state=13)
##

# %%
data.groupby(by="Attack").count()
# Out:
#                           IPV4_SRC_ADDR  IPV4_DST_ADDR  PROTOCOL  L7_PROTO  \
# Attack
# Benign                           332711         332711    332711    332711
# Bot                                2862           2862      2862      2862
# Brute_Force_-Web                     43             43        43        43
# Brute_Force_-XSS                     19             19        19        19
# DDOS_attack-HOIC                  21617          21617     21617     21617
# DDOS_attack-LOIC-UDP                 42             42        42        42
# DDoS_attacks-LOIC-HTTP             6146           6146      6146      6146
# DoS_attacks-GoldenEye               554            554       554       554
# DoS_attacks-Hulk                   8653           8653      8653      8653
# DoS_attacks-SlowHTTPTest            282            282       282       282
# DoS_attacks-Slowloris               190            190       190       190
# FTP-BruteForce                      519            519       519       519
# Infilteration                      2327           2327      2327      2327
# SQL_Injection                         9              9         9         9
# SSH-Bruteforce                     1900           1900      1900      1900
#
#                           IN_BYTES  IN_PKTS  OUT_BYTES  OUT_PKTS  TCP_FLAGS  \
# Attack
# Benign                      332711   332711     332711    332711     332711
# Bot                           2862     2862       2862      2862       2862
# Brute_Force_-Web                43       43         43        43         43
# Brute_Force_-XSS                19       19         19        19         19
# DDOS_attack-HOIC             21617    21617      21617     21617      21617
# DDOS_attack-LOIC-UDP            42       42         42        42         42
# DDoS_attacks-LOIC-HTTP        6146     6146       6146      6146       6146
# DoS_attacks-GoldenEye          554      554        554       554        554
# DoS_attacks-Hulk              8653     8653       8653      8653       8653
# DoS_attacks-SlowHTTPTest       282      282        282       282        282
# DoS_attacks-Slowloris          190      190        190       190        190
# FTP-BruteForce                 519      519        519       519        519
# Infilteration                 2327     2327       2327      2327       2327
# SQL_Injection                    9        9          9         9          9
# SSH-Bruteforce                1900     1900       1900      1900       1900
#
#                           CLIENT_TCP_FLAGS  ...  NUM_PKTS_1024_TO_1514_BYTES  \
# Attack                                      ...
# Benign                              332711  ...                       332711
# Bot                                   2862  ...                         2862
# Brute_Force_-Web                        43  ...                           43
# Brute_Force_-XSS                        19  ...                           19
# DDOS_attack-HOIC                     21617  ...                        21617
# DDOS_attack-LOIC-UDP                    42  ...                           42
# DDoS_attacks-LOIC-HTTP                6146  ...                         6146
# DoS_attacks-GoldenEye                  554  ...                          554
# DoS_attacks-Hulk                      8653  ...                         8653
# DoS_attacks-SlowHTTPTest               282  ...                          282
# DoS_attacks-Slowloris                  190  ...                          190
# FTP-BruteForce                         519  ...                          519
# Infilteration                         2327  ...                         2327
# SQL_Injection                            9  ...                            9
# SSH-Bruteforce                        1900  ...                         1900
#
#                           TCP_WIN_MAX_IN  TCP_WIN_MAX_OUT  ICMP_TYPE  \
# Attack
# Benign                            332711           332711     332711
# Bot                                 2862             2862       2862
# Brute_Force_-Web                      43               43         43
# Brute_Force_-XSS                      19               19         19
# DDOS_attack-HOIC                   21617            21617      21617
# DDOS_attack-LOIC-UDP                  42               42         42
# DDoS_attacks-LOIC-HTTP              6146             6146       6146
# DoS_attacks-GoldenEye                554              554        554
# DoS_attacks-Hulk                    8653             8653       8653
# DoS_attacks-SlowHTTPTest             282              282        282
# DoS_attacks-Slowloris                190              190        190
# FTP-BruteForce                       519              519        519
# Infilteration                       2327             2327       2327
# SQL_Injection                          9                9          9
# SSH-Bruteforce                      1900             1900       1900
#
#                           ICMP_IPV4_TYPE  DNS_QUERY_ID  DNS_QUERY_TYPE  \
# Attack
# Benign                            332711        332711          332711
# Bot                                 2862          2862            2862
# Brute_Force_-Web                      43            43              43
# Brute_Force_-XSS                      19            19              19
# DDOS_attack-HOIC                   21617         21617           21617
# DDOS_attack-LOIC-UDP                  42            42              42
# DDoS_attacks-LOIC-HTTP              6146          6146            6146
# DoS_attacks-GoldenEye                554           554             554
# DoS_attacks-Hulk                    8653          8653            8653
# DoS_attacks-SlowHTTPTest             282           282             282
# DoS_attacks-Slowloris                190           190             190
# FTP-BruteForce                       519           519             519
# Infilteration                       2327          2327            2327
# SQL_Injection                          9             9               9
# SSH-Bruteforce                      1900          1900            1900
#
#                           DNS_TTL_ANSWER  FTP_COMMAND_RET_CODE   Label
# Attack
# Benign                            332711                332711  332711
# Bot                                 2862                  2862    2862
# Brute_Force_-Web                      43                    43      43
# Brute_Force_-XSS                      19                    19      19
# DDOS_attack-HOIC                   21617                 21617   21617
# DDOS_attack-LOIC-UDP                  42                    42      42
# DDoS_attacks-LOIC-HTTP              6146                  6146    6146
# DoS_attacks-GoldenEye                554                   554     554
# DoS_attacks-Hulk                    8653                  8653    8653
# DoS_attacks-SlowHTTPTest             282                   282     282
# DoS_attacks-Slowloris                190                   190     190
# FTP-BruteForce                       519                   519     519
# Infilteration                       2327                  2327    2327
# SQL_Injection                          9                     9       9
# SSH-Bruteforce                      1900                  1900    1900
#
# [15 rows x 42 columns]

# %%
##ADDED
test_data.groupby(by="Attack").count()
##
# Out:
#                           FLOW_START_MILLISECONDS  FLOW_END_MILLISECONDS  \
# Attack
# Benign                                     350293                 350293
# Bot                                          4154                   4154
# Brute_Force_-Web                               32                     32
# Brute_Force_-XSS                               10                     10
# DDOS_attack-HOIC                            20646                  20646
# DDOS_attack-LOIC-UDP                           69                     69
# DDoS_attacks-LOIC-HTTP                       5772                   5772
# DoS_attacks-GoldenEye                        1226                   1226
# DoS_attacks-Hulk                             2002                   2002
# DoS_attacks-SlowHTTPTest                     2111                   2111
# DoS_attacks-Slowloris                         721                    721
# FTP-BruteForce                               7734                   7734
# Infilteration                                3763                   3763
# SQL_Injection                                   9                      9
# SSH-Bruteforce                               3769                   3769
#
#                           IPV4_SRC_ADDR  IPV4_DST_ADDR  PROTOCOL  L7_PROTO  \
# Attack
# Benign                           350293         350293    350293    350293
# Bot                                4154           4154      4154      4154
# Brute_Force_-Web                     32             32        32        32
# Brute_Force_-XSS                     10             10        10        10
# DDOS_attack-HOIC                  20646          20646     20646     20646
# DDOS_attack-LOIC-UDP                 69             69        69        69
# DDoS_attacks-LOIC-HTTP             5772           5772      5772      5772
# DoS_attacks-GoldenEye              1226           1226      1226      1226
# DoS_attacks-Hulk                   2002           2002      2002      2002
# DoS_attacks-SlowHTTPTest           2111           2111      2111      2111
# DoS_attacks-Slowloris               721            721       721       721
# FTP-BruteForce                     7734           7734      7734      7734
# Infilteration                      3763           3763      3763      3763
# SQL_Injection                         9              9         9         9
# SSH-Bruteforce                     3769           3769      3769      3769
#
#                           IN_BYTES  IN_PKTS  OUT_BYTES  OUT_PKTS  ...  \
# Attack                                                            ...
# Benign                      350293   350293     350293    350293  ...
# Bot                           4154     4154       4154      4154  ...
# Brute_Force_-Web                32       32         32        32  ...
# Brute_Force_-XSS                10       10         10        10  ...
# DDOS_attack-HOIC             20646    20646      20646     20646  ...
# DDOS_attack-LOIC-UDP            69       69         69        69  ...
# DDoS_attacks-LOIC-HTTP        5772     5772       5772      5772  ...
# DoS_attacks-GoldenEye         1226     1226       1226      1226  ...
# DoS_attacks-Hulk              2002     2002       2002      2002  ...
# DoS_attacks-SlowHTTPTest      2111     2111       2111      2111  ...
# DoS_attacks-Slowloris          721      721        721       721  ...
# FTP-BruteForce                7734     7734       7734      7734  ...
# Infilteration                 3763     3763       3763      3763  ...
# SQL_Injection                    9        9          9         9  ...
# SSH-Bruteforce                3769     3769       3769      3769  ...
#
#                           FTP_COMMAND_RET_CODE  SRC_TO_DST_IAT_MIN  \
# Attack
# Benign                                  350293              350293
# Bot                                       4154                4154
# Brute_Force_-Web                            32                  32
# Brute_Force_-XSS                            10                  10
# DDOS_attack-HOIC                         20646               20646
# DDOS_attack-LOIC-UDP                        69                  69
# DDoS_attacks-LOIC-HTTP                    5772                5772
# DoS_attacks-GoldenEye                     1226                1226
# DoS_attacks-Hulk                          2002                2002
# DoS_attacks-SlowHTTPTest                  2111                2111
# DoS_attacks-Slowloris                      721                 721
# FTP-BruteForce                            7734                7734
# Infilteration                             3763                3763
# SQL_Injection                                9                   9
# SSH-Bruteforce                            3769                3769
#
#                           SRC_TO_DST_IAT_MAX  SRC_TO_DST_IAT_AVG  \
# Attack
# Benign                                350293              350293
# Bot                                     4154                4154
# Brute_Force_-Web                          32                  32
# Brute_Force_-XSS                          10                  10
# DDOS_attack-HOIC                       20646               20646
# DDOS_attack-LOIC-UDP                      69                  69
# DDoS_attacks-LOIC-HTTP                  5772                5772
# DoS_attacks-GoldenEye                   1226                1226
# DoS_attacks-Hulk                        2002                2002
# DoS_attacks-SlowHTTPTest                2111                2111
# DoS_attacks-Slowloris                    721                 721
# FTP-BruteForce                          7734                7734
# Infilteration                           3763                3763
# SQL_Injection                              9                   9
# SSH-Bruteforce                          3769                3769
#
#                           SRC_TO_DST_IAT_STDDEV  DST_TO_SRC_IAT_MIN  \
# Attack
# Benign                                   350293              350293
# Bot                                        4154                4154
# Brute_Force_-Web                             32                  32
# Brute_Force_-XSS                             10                  10
# DDOS_attack-HOIC                          20646               20646
# DDOS_attack-LOIC-UDP                         69                  69
# DDoS_attacks-LOIC-HTTP                     5772                5772
# DoS_attacks-GoldenEye                      1226                1226
# DoS_attacks-Hulk                           2002                2002
# DoS_attacks-SlowHTTPTest                   2111                2111
# DoS_attacks-Slowloris                       721                 721
# FTP-BruteForce                             7734                7734
# Infilteration                              3763                3763
# SQL_Injection                                 9                   9
# SSH-Bruteforce                             3769                3769
#
#                           DST_TO_SRC_IAT_MAX  DST_TO_SRC_IAT_AVG  \
# Attack
# Benign                                350293              350293
# Bot                                     4154                4154
# Brute_Force_-Web                          32                  32
# Brute_Force_-XSS                          10                  10
# DDOS_attack-HOIC                       20646               20646
# DDOS_attack-LOIC-UDP                      69                  69
# DDoS_attacks-LOIC-HTTP                  5772                5772
# DoS_attacks-GoldenEye                   1226                1226
# DoS_attacks-Hulk                        2002                2002
# DoS_attacks-SlowHTTPTest                2111                2111
# DoS_attacks-Slowloris                    721                 721
# FTP-BruteForce                          7734                7734
# Infilteration                           3763                3763
# SQL_Injection                              9                   9
# SSH-Bruteforce                          3769                3769
#
#                           DST_TO_SRC_IAT_STDDEV   Label
# Attack
# Benign                                   350293  350293
# Bot                                        4154    4154
# Brute_Force_-Web                             32      32
# Brute_Force_-XSS                             10      10
# DDOS_attack-HOIC                          20646   20646
# DDOS_attack-LOIC-UDP                         69      69
# DDoS_attacks-LOIC-HTTP                     5772    5772
# DoS_attacks-GoldenEye                      1226    1226
# DoS_attacks-Hulk                           2002    2002
# DoS_attacks-SlowHTTPTest                   2111    2111
# DoS_attacks-Slowloris                       721     721
# FTP-BruteForce                             7734    7734
# Infilteration                              3763    3763
# SQL_Injection                                 9       9
# SSH-Bruteforce                             3769    3769
#
# [15 rows x 52 columns]

# %%
X = data.drop(columns=["Attack", "Label"])
y = data[["Attack", "Label"]]

# X_train, X_test, y_train, y_test = train_test_split(
#         X, y, test_size=0.3, random_state=13, stratify=y)
# ADDED
X_train, y_train = X, y
X_test = test_data.drop(columns=["Attack", "Label", "FLOW_START_MILLISECONDS", "FLOW_END_MILLISECONDS",
                                 "SRC_TO_DST_IAT_MIN", "SRC_TO_DST_IAT_MAX", "SRC_TO_DST_IAT_AVG",
                                 "SRC_TO_DST_IAT_STDDEV", "DST_TO_SRC_IAT_MIN", "DST_TO_SRC_IAT_MAX",
                                 "DST_TO_SRC_IAT_AVG", "DST_TO_SRC_IAT_STDDEV"])
y_test = test_data[["Attack", "Label"]]
##

# %%
encoder = ce.TargetEncoder(cols=['TCP_FLAGS','L7_PROTO','PROTOCOL',
                                  'CLIENT_TCP_FLAGS','SERVER_TCP_FLAGS','ICMP_TYPE',
                                  'ICMP_IPV4_TYPE','DNS_QUERY_ID','DNS_QUERY_TYPE',
                                  'FTP_COMMAND_RET_CODE'])
encoder.fit(X_train, y_train.Label)

# Transform on training set
X_train = encoder.transform(X_train)

# Transform on testing set
X_test = encoder.transform(X_test)

# %%
X_train.replace([np.inf, -np.inf], np.nan, inplace=True)
X_test.replace([np.inf, -np.inf], np.nan, inplace=True)
X_train.fillna(0, inplace=True)
X_test.fillna(0, inplace=True)

# %%
# (Modified)
scaler = Normalizer()
cols_to_norm = list(set(list(X_train.iloc[:, 2:].columns))) # Ignore first two as the represents IP addresses
scaler.fit(X_train[cols_to_norm])

# Transform on training set
X_train[cols_to_norm] = scaler.transform(X_train[cols_to_norm])
X_train['h'] = X_train.iloc[:, 2:].values.tolist()
X_train['id'] = X_train.index

# Transform on testing set
X_test[cols_to_norm] = scaler.transform(X_test[cols_to_norm])
X_test['h'] = X_test.iloc[:, 2:].values.tolist()
X_test['id'] = X_test.index

train = pd.concat([X_train, y_train], axis=1)
test = pd.concat([X_test, y_test], axis=1)

# %%
X_train.head()
# Out:
#           IPV4_SRC_ADDR IPV4_DST_ADDR      PROTOCOL      L7_PROTO  IN_BYTES  \
# 14549820   172.31.67.20    172.31.0.2  4.716236e-09  3.726003e-09  0.000034
# 13845100   172.31.66.55    172.31.0.2  5.658012e-09  5.282345e-09  0.000049
# 12678473  172.31.64.108    172.31.0.2  6.536759e-09  5.164284e-09  0.000038
# 17430018   172.31.64.85    172.31.0.2  1.209641e-08  9.556615e-09  0.000069
# 9445393    172.31.66.17    172.31.0.2  1.020752e-08  8.064322e-09  0.000054
#
#                IN_PKTS  OUT_BYTES      OUT_PKTS     TCP_FLAGS  \
# 14549820  4.275410e-07   0.000070  4.275410e-07  4.738929e-09
# 13845100  5.129157e-07   0.000115  5.129157e-07  5.685235e-09
# 12678473  5.925768e-07   0.000119  5.925768e-07  6.568210e-09
# 17430018  1.096576e-06   0.000104  1.096576e-06  1.215461e-08
# 9445393   9.253422e-07   0.000113  9.253422e-07  1.025663e-08
#
#           CLIENT_TCP_FLAGS  ...  TCP_WIN_MAX_IN  TCP_WIN_MAX_OUT  \
# 14549820      4.738929e-09  ...             0.0              0.0
# 13845100      5.685235e-09  ...             0.0              0.0
# 12678473      6.568210e-09  ...             0.0              0.0
# 17430018      1.215461e-08  ...             0.0              0.0
# 9445393       1.025663e-08  ...             0.0              0.0
#
#              ICMP_TYPE  ICMP_IPV4_TYPE  DNS_QUERY_ID  DNS_QUERY_TYPE  \
# 14549820  5.035451e-08    5.035451e-08  4.251542e-08    3.431984e-09
# 13845100  6.040970e-08    6.040970e-08  5.260711e-08    4.632277e-09
# 12678473  6.979194e-08    6.979194e-08  6.077753e-08    5.351717e-09
# 17430018  1.291514e-07    1.291514e-07  1.108168e-07    9.903463e-09
# 9445393   1.089841e-07    1.089841e-07  9.620624e-08    7.427965e-09
#
#           DNS_TTL_ANSWER  FTP_COMMAND_RET_CODE  \
# 14549820        0.000026          5.109913e-08
# 13845100        0.000009          6.130301e-08
# 12678473        0.000036          7.082399e-08
# 17430018        0.000066          1.310613e-07
# 9445393         0.000056          1.105957e-07
#
#                                                           h        id
# 14549820  [4.716236267708683e-09, 3.7260034863814994e-09...  14549820
# 13845100  [5.6580115852816764e-09, 5.282345389367056e-09...  13845100
# 12678473  [6.536758516223423e-09, 5.164284323040382e-09,...  12678473
# 17430018  [1.2096406568644908e-08, 9.556614743000617e-09...  17430018
# 9445393   [1.0207518382181603e-08, 8.064322251987137e-09...   9445393
#
# [5 rows x 43 columns]

# %%
lab_enc = preprocessing.LabelEncoder()
lab_enc.fit(data["Attack"])

# Transform on training set
train["Attack"] = lab_enc.transform(train["Attack"])

# Transform on testing set
test["Attack"] = lab_enc.transform(test["Attack"])

# %%
# Training graph (Modified)

train['id'] = train.index

train_g = nx.from_pandas_edgelist(train, "IPV4_SRC_ADDR", "IPV4_DST_ADDR",
           ["h", "Label", "Attack", "id"], create_using=nx.MultiGraph())
train_g = train_g.to_directed()
train_g = dgl.from_networkx(train_g, edge_attrs=['h', 'Attack', 'Label', "id"])
nfeat_weight = torch.ones([train_g.number_of_nodes(),
train_g.edata['h'].shape[1]])
train_g.ndata['h'] = nfeat_weight

test['id'] = test.index

# Testing graph
test_g = nx.from_pandas_edgelist(test, "IPV4_SRC_ADDR", "IPV4_DST_ADDR",
            ["h", "Label", "Attack", "id"], create_using=nx.MultiGraph())

test_g = test_g.to_directed()
test_g = dgl.from_networkx(test_g, edge_attrs=['h', 'Attack', 'Label', "id"])
nfeat_weight = torch.ones([test_g.number_of_nodes(),
test_g.edata['h'].shape[1]])
test_g.ndata['h'] = nfeat_weight

# %%
import torch.nn as nn
import torch.nn.functional as F
import dgl.function as fn
import tqdm
import gc

class SAGELayer(nn.Module):
    def __init__(self, ndim_in, edims, ndim_out, activation):
      super(SAGELayer, self).__init__()
      self.W_apply = nn.Linear(ndim_in + edims , ndim_out)
      self.activation = F.relu
      self.W_edge = nn.Linear(128 * 2, 256)
      self.reset_parameters()

    def reset_parameters(self):
      gain = nn.init.calculate_gain('relu')
      nn.init.xavier_uniform_(self.W_apply.weight, gain=gain)

    def message_func(self, edges):
      return {'m':  edges.data['h']}

    def forward(self, g_dgl, nfeats, efeats):
      with g_dgl.local_scope():
        g = g_dgl
        g.ndata['h'] = nfeats
        g.edata['h'] = efeats
        g.update_all(self.message_func, fn.mean('m', 'h_neigh'))
        g.ndata['h'] = F.relu(self.W_apply(torch.cat([g.ndata['h'], g.ndata['h_neigh']], 2)))

        # Compute edge embeddings
        u, v = g.edges()
        edge = self.W_edge(torch.cat((g.srcdata['h'][u], g.dstdata['h'][v]), 2))
        return g.ndata['h'], edge

# %%
class SAGE(nn.Module):
    def __init__(self, ndim_in, ndim_out, edim,  activation):
      super(SAGE, self).__init__()
      self.layers = nn.ModuleList()
      self.layers.append(SAGELayer(ndim_in, edim, 128, F.relu))

    def forward(self, g, nfeats, efeats, corrupt=False):
      if corrupt:
        e_perm = torch.randperm(g.number_of_edges())
        #n_perm = torch.randperm(g.number_of_nodes())
        efeats = efeats[e_perm]
        #nfeats = nfeats[n_perm]
      for i, layer in enumerate(self.layers):
        #nfeats = layer(g, nfeats, efeats)
        nfeats, e_feats = layer(g, nfeats, efeats)
      #return nfeats.sum(1)
      return nfeats.sum(1), e_feats.sum(1)

# %%
class Discriminator(nn.Module):
    def __init__(self, n_hidden):
      super(Discriminator, self).__init__()
      self.weight = nn.Parameter(torch.Tensor(n_hidden, n_hidden))
      self.reset_parameters()

    def uniform(self, size, tensor):
      bound = 1.0 / math.sqrt(size)
      if tensor is not None:
        tensor.data.uniform_(-bound, bound)

    def reset_parameters(self):
      size = self.weight.size(0)
      self.uniform(size, self.weight)

    def forward(self, features, summary):
      features = torch.matmul(features, torch.matmul(self.weight, summary))
      return features

# %%
class DGI(nn.Module):
    def __init__(self, ndim_in, ndim_out, edim, activation):
      super(DGI, self).__init__()
      self.encoder = SAGE(ndim_in, ndim_out, edim,  F.relu)
      #self.discriminator = Discriminator(128)
      self.discriminator = Discriminator(256)
      self.loss = nn.BCEWithLogitsLoss()

    def forward(self, g, n_features, e_features):
      positive = self.encoder(g, n_features, e_features, corrupt=False)
      negative = self.encoder(g, n_features, e_features, corrupt=True)
      self.loss = nn.BCEWithLogitsLoss()

    def forward(self, g, n_features, e_features):
      positive = self.encoder(g, n_features, e_features, corrupt=False)
      negative = self.encoder(g, n_features, e_features, corrupt=True)

      positive = positive[1]
      negative = negative[1]

      summary = torch.sigmoid(positive.mean(dim=0))

      positive = self.discriminator(positive, summary)
      negative = self.discriminator(negative, summary)

      l1 = self.loss(positive, torch.ones_like(positive))
      l2 = self.loss(negative, torch.zeros_like(negative))

      return l1 + l2

# %%
ndim_in = train_g.ndata['h'].shape[1]
hidden_features = 128
ndim_out = 128
num_layers = 1
edim = train_g.edata['h'].shape[1]
learning_rate = 1e-3
epochs = 4000

# %%
dgi = DGI(ndim_in,
    ndim_out,
    edim,
    F.relu)

dgi = dgi.to('cuda')

dgi_optimizer = torch.optim.Adam(dgi.parameters(),
                lr=1e-3,
                weight_decay=0.)

# %%
# Format node and edge features for E-GraphSAGE
train_g.ndata['h'] = torch.reshape(train_g.ndata['h'],
                                   (train_g.ndata['h'].shape[0], 1,
                                    train_g.ndata['h'].shape[1]))

train_g.edata['h'] = torch.reshape(train_g.edata['h'],
                                   (train_g.edata['h'].shape[0], 1,
                                    train_g.edata['h'].shape[1]))

# %%
# Convert to GPU
train_g = train_g.to('cuda')

# %%
cnt_wait = 0
best = 1e9
best_t = 0
dur = []
node_features = train_g.ndata['h'] 
edge_features = train_g.edata['h']

for epoch in range(epochs):
    dgi.train()
    if epoch >= 3:
        t0 = time.time()

    dgi_optimizer.zero_grad()
    loss = dgi(train_g, node_features, edge_features)
    loss.backward()
    dgi_optimizer.step()

    if loss < best:
        best = loss
        best_t = epoch
        cnt_wait = 0
        torch.save(dgi.state_dict(), 'best_dgi_CSE_v2.pkl')
    else:
        cnt_wait += 1

  # if cnt_wait == patience:
  #     print('Early stopping!')
  #     break

    if epoch >= 3:
        dur.append(time.time() - t0)

    if epoch % 50 == 0:

        print("Epoch {:05d} | Time(s) {:.4f} | Loss {:.4f} | "
            "ETputs(KTEPS) {:.2f}".format(epoch, np.mean(dur),
              loss.item(),
              train_g.num_edges() / np.mean(dur) / 1000))
# Out:
# /home/kienho/miniforge3/envs/nlp-env/lib/python3.9/site-packages/numpy/_core/fromnumeric.py:3596: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/kienho/miniforge3/envs/nlp-env/lib/python3.9/site-packages/numpy/_core/_methods.py:138: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# Epoch 00000 | Time(s) nan | Loss 1.9918 | ETputs(KTEPS) nan
# Epoch 00050 | Time(s) 0.5561 | Loss 1.3588 | ETputs(KTEPS) 1357.35
# Epoch 00100 | Time(s) 0.5575 | Loss 1.0263 | ETputs(KTEPS) 1353.72
# Epoch 00150 | Time(s) 0.5579 | Loss 0.3042 | ETputs(KTEPS) 1352.89
# Epoch 00200 | Time(s) 0.5581 | Loss 0.2117 | ETputs(KTEPS) 1352.46
# Epoch 00250 | Time(s) 0.5580 | Loss 0.4086 | ETputs(KTEPS) 1352.57
# Epoch 00300 | Time(s) 0.5579 | Loss 0.3024 | ETputs(KTEPS) 1352.77
# Epoch 00350 | Time(s) 0.5579 | Loss 0.2262 | ETputs(KTEPS) 1352.90
# Epoch 00400 | Time(s) 0.5579 | Loss 0.1996 | ETputs(KTEPS) 1352.89
# Epoch 00450 | Time(s) 0.5579 | Loss 0.1935 | ETputs(KTEPS) 1352.81
# Epoch 00500 | Time(s) 0.5579 | Loss 0.1933 | ETputs(KTEPS) 1352.85
# Epoch 00550 | Time(s) 0.5578 | Loss 0.1896 | ETputs(KTEPS) 1352.99
# Epoch 00600 | Time(s) 0.5578 | Loss 0.1879 | ETputs(KTEPS) 1353.09
# Epoch 00650 | Time(s) 0.5578 | Loss 0.1846 | ETputs(KTEPS) 1353.15
# Epoch 00700 | Time(s) 0.5577 | Loss 0.1823 | ETputs(KTEPS) 1353.28
# Epoch 00750 | Time(s) 0.5577 | Loss 0.1812 | ETputs(KTEPS) 1353.34
# Epoch 00800 | Time(s) 0.5576 | Loss 0.1790 | ETputs(KTEPS) 1353.48
# Epoch 00850 | Time(s) 0.5577 | Loss 0.1743 | ETputs(KTEPS) 1353.46
# Epoch 00900 | Time(s) 0.5576 | Loss 0.1720 | ETputs(KTEPS) 1353.64
# Epoch 00950 | Time(s) 0.5576 | Loss 0.1778 | ETputs(KTEPS) 1353.62
# Epoch 01000 | Time(s) 0.5576 | Loss 0.1756 | ETputs(KTEPS) 1353.70
# Epoch 01050 | Time(s) 0.5576 | Loss 0.1719 | ETputs(KTEPS) 1353.67
# Epoch 01100 | Time(s) 0.5575 | Loss 0.1693 | ETputs(KTEPS) 1353.73
# Epoch 01150 | Time(s) 0.5575 | Loss 0.1672 | ETputs(KTEPS) 1353.73
# Epoch 01200 | Time(s) 0.5575 | Loss 0.1655 | ETputs(KTEPS) 1353.73
# Epoch 01250 | Time(s) 0.5575 | Loss 0.1636 | ETputs(KTEPS) 1353.70
# Epoch 01300 | Time(s) 0.5576 | Loss 0.1609 | ETputs(KTEPS) 1353.68
# Epoch 01350 | Time(s) 0.5576 | Loss 0.1574 | ETputs(KTEPS) 1353.68
# Epoch 01400 | Time(s) 0.5575 | Loss 0.1546 | ETputs(KTEPS) 1353.72
# Epoch 01450 | Time(s) 0.5575 | Loss 0.1666 | ETputs(KTEPS) 1353.72
# Epoch 01500 | Time(s) 0.5576 | Loss 0.1476 | ETputs(KTEPS) 1353.68
# Epoch 01550 | Time(s) 0.5575 | Loss 0.1410 | ETputs(KTEPS) 1353.72
# Epoch 01600 | Time(s) 0.5575 | Loss 0.1434 | ETputs(KTEPS) 1353.74
# Epoch 01650 | Time(s) 0.5575 | Loss 0.1406 | ETputs(KTEPS) 1353.75
# Epoch 01700 | Time(s) 0.5575 | Loss 0.1805 | ETputs(KTEPS) 1353.76
# Epoch 01750 | Time(s) 0.5575 | Loss 1.4078 | ETputs(KTEPS) 1353.79
# Epoch 01800 | Time(s) 0.5575 | Loss 0.2930 | ETputs(KTEPS) 1353.83
# Epoch 01850 | Time(s) 0.5575 | Loss 0.2260 | ETputs(KTEPS) 1353.89
# Epoch 01900 | Time(s) 0.5575 | Loss 0.2083 | ETputs(KTEPS) 1353.93
# Epoch 01950 | Time(s) 0.5574 | Loss 0.1921 | ETputs(KTEPS) 1353.97
# Epoch 02000 | Time(s) 0.5574 | Loss 0.1830 | ETputs(KTEPS) 1353.99
# Epoch 02050 | Time(s) 0.5574 | Loss 0.1762 | ETputs(KTEPS) 1354.01
# Epoch 02100 | Time(s) 0.5574 | Loss 0.1606 | ETputs(KTEPS) 1354.08
# Epoch 02150 | Time(s) 0.5574 | Loss 0.1663 | ETputs(KTEPS) 1354.13
# Epoch 02200 | Time(s) 0.5574 | Loss 0.1462 | ETputs(KTEPS) 1354.15
# Epoch 02250 | Time(s) 0.5574 | Loss 0.1356 | ETputs(KTEPS) 1354.17
# Epoch 02300 | Time(s) 0.5574 | Loss 0.1501 | ETputs(KTEPS) 1354.16
# Epoch 02350 | Time(s) 0.5574 | Loss 0.1224 | ETputs(KTEPS) 1354.18
# Epoch 02400 | Time(s) 0.5573 | Loss 0.3081 | ETputs(KTEPS) 1354.21
# Epoch 02450 | Time(s) 0.5573 | Loss 0.2570 | ETputs(KTEPS) 1354.26
# Epoch 02500 | Time(s) 0.5573 | Loss 0.2495 | ETputs(KTEPS) 1354.28
# Epoch 02550 | Time(s) 0.5573 | Loss 0.2456 | ETputs(KTEPS) 1354.34
# Epoch 02600 | Time(s) 0.5573 | Loss 0.2412 | ETputs(KTEPS) 1354.35
# Epoch 02650 | Time(s) 0.5573 | Loss 0.2351 | ETputs(KTEPS) 1354.36
# Epoch 02700 | Time(s) 0.5573 | Loss 0.2299 | ETputs(KTEPS) 1354.38
# Epoch 02750 | Time(s) 0.5573 | Loss 0.2227 | ETputs(KTEPS) 1354.43
# Epoch 02800 | Time(s) 0.5572 | Loss 0.2114 | ETputs(KTEPS) 1354.43
# Epoch 02850 | Time(s) 0.5572 | Loss 0.2011 | ETputs(KTEPS) 1354.47
# Epoch 02900 | Time(s) 0.5572 | Loss 0.1838 | ETputs(KTEPS) 1354.48
# Epoch 02950 | Time(s) 0.5572 | Loss 0.1740 | ETputs(KTEPS) 1354.49
# Epoch 03000 | Time(s) 0.5572 | Loss 0.1636 | ETputs(KTEPS) 1354.53
# Epoch 03050 | Time(s) 0.5572 | Loss 0.1547 | ETputs(KTEPS) 1354.54
# Epoch 03100 | Time(s) 0.5572 | Loss 0.1440 | ETputs(KTEPS) 1354.55
# Epoch 03150 | Time(s) 0.5572 | Loss 0.1346 | ETputs(KTEPS) 1354.58
# Epoch 03200 | Time(s) 0.5572 | Loss 0.1307 | ETputs(KTEPS) 1354.59
# Epoch 03250 | Time(s) 0.5572 | Loss 0.1215 | ETputs(KTEPS) 1354.58
# Epoch 03300 | Time(s) 0.5572 | Loss 0.1166 | ETputs(KTEPS) 1354.61
# Epoch 03350 | Time(s) 0.5572 | Loss 0.1100 | ETputs(KTEPS) 1354.62
# Epoch 03400 | Time(s) 0.5572 | Loss 0.1052 | ETputs(KTEPS) 1354.64
# Epoch 03450 | Time(s) 0.5572 | Loss 0.0985 | ETputs(KTEPS) 1354.64
# Epoch 03500 | Time(s) 0.5572 | Loss 0.1022 | ETputs(KTEPS) 1354.64
# Epoch 03550 | Time(s) 0.5572 | Loss 0.1469 | ETputs(KTEPS) 1354.65
# Epoch 03600 | Time(s) 0.5572 | Loss 0.0914 | ETputs(KTEPS) 1354.63
# Epoch 03650 | Time(s) 0.5572 | Loss 0.0876 | ETputs(KTEPS) 1354.64
# Epoch 03700 | Time(s) 0.5572 | Loss 0.0833 | ETputs(KTEPS) 1354.66
# Epoch 03750 | Time(s) 0.5572 | Loss 0.0811 | ETputs(KTEPS) 1354.67
# Epoch 03800 | Time(s) 0.5572 | Loss 0.0732 | ETputs(KTEPS) 1354.67
# Epoch 03850 | Time(s) 0.5571 | Loss 0.0708 | ETputs(KTEPS) 1354.68
# Epoch 03900 | Time(s) 0.5571 | Loss 0.0669 | ETputs(KTEPS) 1354.68
# Epoch 03950 | Time(s) 0.5571 | Loss 0.0658 | ETputs(KTEPS) 1354.69

# %%
dgi.load_state_dict(torch.load('best_dgi_CSE_v2.pkl'))
# Out:
# /tmp/ipykernel_15811/1688994637.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   dgi.load_state_dict(torch.load('best_dgi_CSE_v2.pkl'))
# <All keys matched successfully>

# %%
training_emb = dgi.encoder(train_g, train_g.ndata['h'], train_g.edata['h'])[1]
training_emb = training_emb.detach().cpu().numpy()

# %%
test_g.ndata['h'] = torch.reshape(test_g.ndata['h'],
                                   (test_g.ndata['h'].shape[0], 1,
                                    test_g.ndata['h'].shape[1]))



test_g.edata['h'] = torch.reshape(test_g.edata['h'],
                                   (test_g.edata['h'].shape[0], 1,
                                    test_g.edata['h'].shape[1]))

# %%
# Convert to GPU
test_g = test_g.to('cuda')

# %%
testing_emb = dgi.encoder(test_g, test_g.ndata['h'], test_g.edata['h'])[1]
testing_emb = testing_emb.detach().cpu().numpy()

# %%
# Multimodal (Fusion) Learning

df_train = pd.DataFrame(training_emb,)
# map the id to the original data
df_train['id'] = train_g.edata['id'].detach().cpu().numpy()


df_raw_train = pd.DataFrame(X_train.drop(columns=["IPV4_SRC_ADDR", "IPV4_DST_ADDR", "h"]))
df_fuse_train = pd.merge(df_train, df_raw_train, on='id', how='left')
df_fuse_train = df_fuse_train.drop(columns=["id"])
df_fuse_train["Attacks"] = train_g.edata['Attack'].detach().cpu().numpy()
df_fuse_train["Label"] = train_g.edata['Label'].detach().cpu().numpy()

df_test = pd.DataFrame(testing_emb,)
# map the id to the original data
df_test['id'] = test_g.edata['id'].detach().cpu().numpy()

df_raw_test = pd.DataFrame(X_test.drop(columns=["IPV4_SRC_ADDR", "IPV4_DST_ADDR", "h"]))
df_raw_test = pd.merge(df_test, df_raw_test, on='id', how='left')
df_fuse_test = df_raw_test.drop(columns=["id"])
df_fuse_test["Attacks"] = test_g.edata['Attack'].detach().cpu().numpy()
df_fuse_test["Label"] = test_g.edata['Label'].detach().cpu().numpy()

# %% [markdown]
# # Embeddings CBLOF  Embeddings

# %%
import torch
import dgl
import numpy as np
import pandas as pd
import torch.optim as optim
import time
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, f1_score
from sklearn.ensemble import IsolationForest
import gc

from tqdm import tqdm
import itertools

# %%
benign_fuse_train_samples = df_fuse_train[df_fuse_train.Label == 0].drop(columns=["Label", "Attacks"])
normal_fuse_train_samples = df_fuse_train.drop(columns=["Label", "Attacks"])

fuse_train_labels = df_fuse_train["Label"]
fuse_test_labels = df_fuse_test["Label"]

fuse_test_samples = df_fuse_test.drop(columns=["Label", "Attacks"])

# %%
fuse_test_samples
# Out:
#                0         1         2         3         4         5         6  \
# 0       0.110089  0.026318 -0.051922 -0.186258 -0.004434 -0.180387  0.074419
# 1       0.110089  0.026318 -0.051922 -0.186258 -0.004434 -0.180387  0.074419
# 2       0.110089  0.026318 -0.051922 -0.186258 -0.004434 -0.180387  0.074419
# 3       0.110089  0.026318 -0.051922 -0.186258 -0.004434 -0.180387  0.074419
# 4       0.110089  0.026318 -0.051922 -0.186258 -0.004434 -0.180387  0.074419
# ...          ...       ...       ...       ...       ...       ...       ...
# 802502  0.067559  0.000833 -0.003197  0.011279 -0.010001 -0.051152 -0.016778
# 802503  0.067559  0.000833 -0.003197  0.011279 -0.010001 -0.051152 -0.016778
# 802504  0.067559  0.000833 -0.003197  0.011279 -0.010001 -0.051152 -0.016778
# 802505  0.067559  0.000833 -0.003197  0.011279 -0.010001 -0.051152 -0.016778
# 802506  0.067559  0.000833 -0.003197  0.011279 -0.010001 -0.051152 -0.016778
#
#                7         8         9  ...  NUM_PKTS_512_TO_1024_BYTES  \
# 0       0.073820  0.092856  0.128640  ...                    0.000015
# 1       0.073820  0.092856  0.128640  ...                    0.000015
# 2       0.073820  0.092856  0.128640  ...                    0.000011
# 3       0.073820  0.092856  0.128640  ...                    0.000015
# 4       0.073820  0.092856  0.128640  ...                    0.000000
# ...          ...       ...       ...  ...                         ...
# 802502  0.067527  0.024838  0.058037  ...                    0.000015
# 802503  0.067527  0.024838  0.058037  ...                    0.000018
# 802504  0.067527  0.024838  0.058037  ...                    0.000018
# 802505  0.067527  0.024838  0.058037  ...                    0.000017
# 802506  0.067527  0.024838  0.058037  ...                    0.000020
#
#         NUM_PKTS_1024_TO_1514_BYTES  TCP_WIN_MAX_IN  TCP_WIN_MAX_OUT  \
# 0                          0.000015        0.125056         0.977001
# 1                          0.000015        0.125216         0.978247
# 2                          0.000011        0.703052         0.700425
# 3                          0.000015        0.125073         0.977136
# 4                          0.000000        0.115296         0.900751
# ...                             ...             ...              ...
# 802502                     0.000007        0.197921         0.197656
# 802503                     0.000009        0.235851         0.235535
# 802504                     0.000009        0.235427         0.235112
# 802505                     0.000009        0.229772         0.229465
# 802506                     0.000010        0.262999         0.262647
#
#            ICMP_TYPE  ICMP_IPV4_TYPE  DNS_QUERY_ID  DNS_QUERY_TYPE  \
# 0       1.797943e-06    1.797943e-06      0.000003        0.000003
# 1       1.800235e-06    1.800235e-06      0.000003        0.000003
# 2       1.288969e-06    1.288969e-06      0.000002        0.000002
# 3       1.798190e-06    1.798190e-06      0.000003        0.000003
# 4       1.657622e-06    1.657622e-06      0.000003        0.000003
# ...              ...             ...           ...             ...
# 802502  8.671126e-07    8.671126e-07      0.000001        0.000001
# 802503  1.033286e-06    1.033286e-06      0.000002        0.000002
# 802504  1.031429e-06    1.031429e-06      0.000002        0.000002
# 802505  1.006655e-06    1.006655e-06      0.000002        0.000002
# 802506  1.152226e-06    1.152226e-06      0.000002        0.000002
#
#         DNS_TTL_ANSWER  FTP_COMMAND_RET_CODE
# 0                  0.0          1.824530e-06
# 1                  0.0          1.826856e-06
# 2                  0.0          1.308029e-06
# 3                  0.0          1.824781e-06
# 4                  0.0          1.682134e-06
# ...                ...                   ...
# 802502             0.0          8.799351e-07
# 802503             0.0          1.048566e-06
# 802504             0.0          1.046682e-06
# 802505             0.0          1.021541e-06
# 802506             0.0          1.169265e-06
#
# [802507 rows x 295 columns]

# %%
contamination = [0.001, 0.01, 0.04, 0.05, 0.1, 0.2]

# %%
from pyod.models.cblof import CBLOF
n_est = [5,6,7,9,10] # cant be lower than 5 or 4
params = list(itertools.product(n_est, contamination))
score = -1
bs = None
for n_est, con in tqdm(params):
    
    clf_if = CBLOF(n_clusters=n_est, contamination=con)
    clf_if.fit(benign_fuse_train_samples)
    y_pred = clf_if.predict(fuse_test_samples)
    test_pred = y_pred

    f1 = f1_score(fuse_test_labels, test_pred, average='macro')

    if f1 > score:
        score = f1
        best_params = {'n_estimators': n_est,
                       "con": con
                }
        bs = test_pred
    del clf_if
    gc.collect()


print(best_params)
print(score)
print(classification_report(fuse_test_labels, bs, digits=4))
# Out:
# 100%|██████████| 30/30 [04:38<00:00,  9.30s/it]
# {'n_estimators': 5, 'con': 0.001}
# 0.40228866639746824
#               precision    recall  f1-score   support
#
#            0     0.8353    0.7226    0.7748    698471
#            1     0.0227    0.0432    0.0297    104036
#
#     accuracy                         0.6345    802507
#    macro avg     0.4290    0.3829    0.4023    802507
# weighted avg     0.7299    0.6345    0.6782    802507

# %%
n_est = [5,6,7,9,10]
contamination = [0.001, 0.01, 0.04, 0.05, 0.1, 0.2]
params = list(itertools.product(n_est, contamination))
score = -1
bs = None
for n_est, con in tqdm(params):
    
    clf_if = CBLOF(n_clusters=n_est, contamination=con)
    clf_if.fit(normal_fuse_train_samples)
    y_pred = clf_if.predict(fuse_test_samples)
    test_pred = y_pred

    f1 = f1_score(fuse_test_labels, test_pred, average='macro')

    if f1 > score:
        score = f1
        best_params = {'n_estimators': n_est,
                       "con": con
                }
        bs = test_pred
    del clf_if
    gc.collect()


print(best_params)
print(score)
print(classification_report(fuse_test_labels, bs, digits=4))
# Out:
# 100%|██████████| 30/30 [05:00<00:00, 10.01s/it]
# {'n_estimators': 10, 'con': 0.01}
# 0.4013096419974923
#               precision    recall  f1-score   support
#
#            0     0.8342    0.6107    0.7052    698471
#            1     0.0661    0.1851    0.0974    104036
#
#     accuracy                         0.5555    802507
#    macro avg     0.4502    0.3979    0.4013    802507
# weighted avg     0.7346    0.5555    0.6264    802507

# %%
# HBOS  Embeddings+Raw (Multimodal)

# %%
contamination = [0.001, 0.01, 0.04, 0.05, 0.1, 0.2]

# %%
from pyod.models.hbos import HBOS

n_est = [5,10,15,20,25,30]
params = list(itertools.product(n_est, contamination))
score = -1
bs = None
for n_est, con in tqdm(params):
    
    clf_if = HBOS(n_bins=n_est, contamination=con)
    clf_if.fit(benign_fuse_train_samples)
    y_pred = clf_if.predict(fuse_test_samples)
    test_pred = y_pred

    f1 = f1_score(fuse_test_labels, test_pred, average='macro')

    if f1 > score:
        score = f1
        best_params = {'n_estimators': n_est,
                       "con": con
                }
        bs = test_pred
    del clf_if
    gc.collect()


print(best_params)
print(score)
print(classification_report(fuse_test_labels, bs, digits=4))
# Out:
#   0%|          | 0/36 [00:00<?, ?it/s]
# 100%|██████████| 36/36 [05:21<00:00,  8.92s/it]
# {'n_estimators': 5, 'con': 0.001}
# 0.37846815552785684
#               precision    recall  f1-score   support
#
#            0     0.8219    0.6560    0.7296    698471
#            1     0.0195    0.0458    0.0273    104036
#
#     accuracy                         0.5769    802507
#    macro avg     0.4207    0.3509    0.3785    802507
# weighted avg     0.7179    0.5769    0.6386    802507

# %%
n_est = [5,10,15,20,25,30]
contamination = [0.001, 0.01, 0.04, 0.05, 0.1, 0.2]
params = list(itertools.product(n_est, contamination))
score = -1
bs = None
for n_est, con in tqdm(params):
    
    clf_if = HBOS(n_bins=n_est, contamination=con)
    clf_if.fit(normal_fuse_train_samples)
    y_pred = clf_if.predict(fuse_test_samples)
    test_pred = y_pred

    f1 = f1_score(fuse_test_labels, test_pred, average='macro')

    if f1 > score:
        score = f1
        best_params = {'n_estimators': n_est,
                       "con": con
                }
        bs = test_pred
    del clf_if
    gc.collect()


print(best_params)
print(score)
print(classification_report(fuse_test_labels, bs, digits=4))
# Out:
# 100%|██████████| 36/36 [05:39<00:00,  9.43s/it]
# {'n_estimators': 5, 'con': 0.001}
# 0.3578868148761849
#               precision    recall  f1-score   support
#
#            0     0.8092    0.6025    0.6907    698471
#            1     0.0171    0.0465    0.0250    104036
#
#     accuracy                         0.5304    802507
#    macro avg     0.4132    0.3245    0.3579    802507
# weighted avg     0.7066    0.5304    0.6044    802507

# %%
##  PCA  Emb+Raw (Multimodal/Fusion) Learning

# %%
from pyod.models.pca import PCA
n_est = [5,10,15,20,25,30]
cont = [0.001, 0.01, 0.04, 0.05, 0.1, 0.2]
params = list(itertools.product(n_est, cont))
score = -1
bs = None

for n_est, con in tqdm(params):
    clf_if = PCA(n_components=n_est, contamination=con)
    clf_if.fit(benign_fuse_train_samples)
    y_pred = clf_if.predict(fuse_test_samples)
    test_pred = y_pred

    f1 = f1_score(fuse_test_labels, test_pred, average='macro')

    if f1 > score:
        score = f1
        best_params = {'n_estimators': n_est,
                       "con": con
                }
        bs = test_pred
    del clf_if
    gc.collect()


print(best_params)
print(score)
print(classification_report(fuse_test_labels, bs, digits=4))
# Out:
#   0%|          | 0/36 [00:00<?, ?it/s]
# 100%|██████████| 36/36 [03:59<00:00,  6.67s/it]
# {'n_estimators': 10, 'con': 0.001}
# 0.3606674228508121
#               precision    recall  f1-score   support
#
#            0     0.8287    0.4315    0.5675    698471
#            1     0.0951    0.4012    0.1538    104036
#
#     accuracy                         0.4276    802507
#    macro avg     0.4619    0.4164    0.3607    802507
# weighted avg     0.7336    0.4276    0.5139    802507

# %%
n_est = [5,10,15,20,25,30]
cont = [0.001, 0.01, 0.04, 0.05, 0.1, 0.2]
params = list(itertools.product(n_est, cont))
score = -1
bs = None

for n_est, con in tqdm(params):
    clf_if = PCA(n_components=n_est, contamination=con)
    clf_if.fit(normal_fuse_train_samples)
    y_pred = clf_if.predict(fuse_test_samples)
    test_pred = y_pred

    f1 = f1_score(fuse_test_labels, test_pred, average='macro')

    if f1 > score:
        score = f1
        best_params = {'n_estimators': n_est,
                       "con": con
                }
        bs = test_pred
    del clf_if
    gc.collect()


print(best_params)
print(score)
print(classification_report(fuse_test_labels, bs, digits=4))
# Out:
# 100%|██████████| 36/36 [04:04<00:00,  6.80s/it]
# {'n_estimators': 10, 'con': 0.1}
# 0.35221219358003625
#               precision    recall  f1-score   support
#
#            0     0.8562    0.3553    0.5022    698471
#            1     0.1217    0.5995    0.2023    104036
#
#     accuracy                         0.3869    802507
#    macro avg     0.4889    0.4774    0.3522    802507
# weighted avg     0.7610    0.3869    0.4633    802507

# %%
##  IF  Emb+Raw

# %%
for i in range(len(benign_fuse_train_samples.columns)):
    benign_fuse_train_samples.rename(columns={benign_fuse_train_samples.columns[i]: f"feature {i}"}, inplace=True)

for i in range(len(normal_fuse_train_samples.columns)):
    normal_fuse_train_samples.rename(columns={normal_fuse_train_samples.columns[i]: f"feature {i}"}, inplace=True)

for i in range(len(fuse_test_samples.columns)):
    fuse_test_samples.rename(columns={fuse_test_samples.columns[i]: f"feature {i}"}, inplace=True)

# %%
from sklearn.ensemble import IsolationForest
n_est = [20, 50, 100, 150]
cont = [0.001, 0.01, 0.04, 0.05, 0.1, 0.2]
params = list(itertools.product(n_est, cont))
score = -1
bs = None

for n_est, con in tqdm(params):
    clf_if = IsolationForest(n_estimators=n_est, contamination=con)
    clf_if.fit(benign_fuse_train_samples.to_numpy())
    y_pred = clf_if.predict(fuse_test_samples)
    test_pred = list(map(lambda x : 0 if x == 1 else 1, y_pred))

    f1 = f1_score(fuse_test_labels, test_pred, average='macro')

    if f1 > score:
        score = f1
        best_params = {'n_estimators': n_est,
                       "con": con
                }
        bs = test_pred
    del clf_if
    gc.collect()


print(best_params)
print(score)
print(classification_report(fuse_test_labels, bs, digits=4))
# Out:
#   0%|          | 0/24 [00:00<?, ?it/s]/home/kienho/miniforge3/envs/nlp-env/lib/python3.9/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but IsolationForest was fitted without feature names
#   warnings.warn(
#   4%|▍         | 1/24 [00:02<00:49,  2.13s/it]/home/kienho/miniforge3/envs/nlp-env/lib/python3.9/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but IsolationForest was fitted without feature names
#   warnings.warn(
#   8%|▊         | 2/24 [00:04<00:46,  2.14s/it]/home/kienho/miniforge3/envs/nlp-env/lib/python3.9/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but IsolationForest was fitted without feature names
#   warnings.warn(
#  12%|█▎        | 3/24 [00:06<00:44,  2.13s/it]/home/kienho/miniforge3/envs/nlp-env/lib/python3.9/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but IsolationForest was fitted without feature names
#   warnings.warn(
#  17%|█▋        | 4/24 [00:08<00:42,  2.13s/it]/home/kienho/miniforge3/envs/nlp-env/lib/python3.9/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but IsolationForest was fitted without feature names
#   warnings.warn(
#  21%|██        | 5/24 [00:10<00:40,  2.12s/it]/home/kienho/miniforge3/envs/nlp-env/lib/python3.9/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but IsolationForest was fitted without feature names
#   warnings.warn(
#  25%|██▌       | 6/24 [00:12<00:38,  2.12s/it]/home/kienho/miniforge3/envs/nlp-env/lib/python3.9/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but IsolationForest was fitted without feature names
#   warnings.warn(
#  29%|██▉       | 7/24 [00:15<00:39,  2.33s/it]/home/kienho/miniforge3/envs/nlp-env/lib/python3.9/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but IsolationForest was fitted without feature names
#   warnings.warn(
#  33%|███▎      | 8/24 [00:18<00:39,  2.46s/it]/home/kienho/miniforge3/envs/nlp-env/lib/python3.9/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but IsolationForest was fitted without feature names
#   warnings.warn(
#  38%|███▊      | 9/24 [00:20<00:38,  2.55s/it]/home/kienho/miniforge3/envs/nlp-env/lib/python3.9/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but IsolationForest was fitted without feature names
#   warnings.warn(
#  42%|████▏     | 10/24 [00:23<00:36,  2.61s/it]/home/kienho/miniforge3/envs/nlp-env/lib/python3.9/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but IsolationForest was fitted without feature names
#   warnings.warn(
#  46%|████▌     | 11/24 [00:26<00:34,  2.65s/it]/home/kienho/miniforge3/envs/nlp-env/lib/python3.9/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but IsolationForest was fitted without feature names
#   warnings.warn(
#  50%|█████     | 12/24 [00:29<00:32,  2.68s/it]/home/kienho/miniforge3/envs/nlp-env/lib/python3.9/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but IsolationForest was fitted without feature names
#   warnings.warn(
#  54%|█████▍    | 13/24 [00:33<00:33,  3.02s/it]/home/kienho/miniforge3/envs/nlp-env/lib/python3.9/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but IsolationForest was fitted without feature names
#   warnings.warn(
#  58%|█████▊    | 14/24 [00:36<00:32,  3.26s/it]/home/kienho/miniforge3/envs/nlp-env/lib/python3.9/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but IsolationForest was fitted without feature names
#   warnings.warn(
#  62%|██████▎   | 15/24 [00:40<00:30,  3.44s/it]/home/kienho/miniforge3/envs/nlp-env/lib/python3.9/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but IsolationForest was fitted without feature names
#   warnings.warn(
#  67%|██████▋   | 16/24 [00:44<00:28,  3.55s/it]/home/kienho/miniforge3/envs/nlp-env/lib/python3.9/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but IsolationForest was fitted without feature names
#   warnings.warn(
#  71%|███████   | 17/24 [00:48<00:25,  3.61s/it]/home/kienho/miniforge3/envs/nlp-env/lib/python3.9/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but IsolationForest was fitted without feature names
#   warnings.warn(
#  75%|███████▌  | 18/24 [00:52<00:21,  3.67s/it]/home/kienho/miniforge3/envs/nlp-env/lib/python3.9/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but IsolationForest was fitted without feature names
#   warnings.warn(
#  79%|███████▉  | 19/24 [00:56<00:20,  4.02s/it]/home/kienho/miniforge3/envs/nlp-env/lib/python3.9/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but IsolationForest was fitted without feature names
#   warnings.warn(
#  83%|████████▎ | 20/24 [01:01<00:17,  4.26s/it]/home/kienho/miniforge3/envs/nlp-env/lib/python3.9/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but IsolationForest was fitted without feature names
#   warnings.warn(
#  88%|████████▊ | 21/24 [01:06<00:13,  4.46s/it]/home/kienho/miniforge3/envs/nlp-env/lib/python3.9/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but IsolationForest was fitted without feature names
#   warnings.warn(
#  92%|█████████▏| 22/24 [01:11<00:09,  4.58s/it]/home/kienho/miniforge3/envs/nlp-env/lib/python3.9/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but IsolationForest was fitted without feature names
#   warnings.warn(
#  96%|█████████▌| 23/24 [01:16<00:04,  4.65s/it]/home/kienho/miniforge3/envs/nlp-env/lib/python3.9/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but IsolationForest was fitted without feature names
#   warnings.warn(
# 100%|██████████| 24/24 [01:21<00:00,  3.38s/it]
# {'n_estimators': 20, 'con': 0.001}
# 0.46531686753346685
#               precision    recall  f1-score   support
#
#            0     0.8701    0.9975    0.9295    698471
#            1     0.0338    0.0006    0.0012    104036
#
#     accuracy                         0.8683    802507
#    macro avg     0.4520    0.4990    0.4653    802507
# weighted avg     0.7617    0.8683    0.8091    802507

# %%
from sklearn.ensemble import IsolationForest

n_est = [20, 50, 100, 150]
cont = [0.001, 0.01, 0.04, 0.05, 0.1, 0.2]
params = list(itertools.product(n_est, cont))
score = -1
bs = None

for n_est, con in tqdm(params):
    clf_if = IsolationForest(n_estimators=n_est, contamination=con)
    clf_if.fit(normal_fuse_train_samples)
    y_pred = clf_if.predict(fuse_test_samples)
    test_pred = list(map(lambda x : 0 if x == 1 else 1, y_pred))

    f1 = f1_score(fuse_test_labels, test_pred, average='macro')

    if f1 > score:
        score = f1
        best_params = {'n_estimators': n_est,
                       "con": con
                }
        bs = test_pred
    del clf_if
    gc.collect()


print(best_params)
print(score)
print(classification_report(fuse_test_labels, bs, digits=4))
# Out:
# 100%|██████████| 24/24 [01:26<00:00,  3.61s/it]
# {'n_estimators': 50, 'con': 0.001}
# 0.46537751706439784
#               precision    recall  f1-score   support
#
#            0     0.8703    0.9998    0.9306    698471
#            1     0.0545    0.0001    0.0002    104036
#
#     accuracy                         0.8702    802507
#    macro avg     0.4624    0.4999    0.4654    802507
# weighted avg     0.7646    0.8702    0.8100    802507
